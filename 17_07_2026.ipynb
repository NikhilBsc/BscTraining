# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilBsc/BscTraining/blob/main/17_07_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #q1
#
# Act as an AI tutor. Explain the difference between Artificial Intelligence (AI), Machine Learning (ML), Deep Learning (DL), and Generative AI as layered concepts. Use simple language suitable for a first-year college student. Include one real-world example for each concept and explain how they are related.

# %% [markdown]
# #q2
#
# Explain how an AI model processes a user's prompt. Describe the stages of tokenization, understanding context, and predicting the next token. Use a simple real-life analogy that a non-technical person can easily understand.

# %% [markdown]
# #q3
#
# Explain why an AI model does not simply search and copy answers from the internet. Describe how a Large Language Model generates responses and explain the role of probability in predicting the next word. Keep the explanation simple and easy to understand.

# %% [markdown]
# #q4
#
# Explain what a context window is, why it has a limit, and what happens when a conversation exceeds that limit. Include a simple numerical example to make the concept easier to understand.

# %% [markdown]
# #q5
#
# Compare Training and Inference in a two-column table. Explain what happens during each phase, when it occurs, and its purpose. Keep the explanation simple and beginner-friendly.

# %% [markdown]
# #q6
#
# Poor Prompt:
#
# What is Machine Learning?
#
# Improved Prompt:
#
# Act as a computer science teacher. Explain Machine Learning to a first-year engineering student using simple language. Include a real-world example and explain why Machine Learning is important.
#
# Why is it better?
#
# The second prompt clearly defines the role, audience, and expected output, resulting in a more accurate response.

# %% [markdown]
# #q7
#
# Role: You are a cloud computing expert.
# Task: Explain Cloud Computing.
# Context: The audience is a non-technical business owner.
# Instructions: Use simple language and include one real-world example.
# Constraints: Avoid technical jargon and keep the explanation under 200 words.
# Output Format: Use bullet points with a short conclusion.

# %% [markdown]
# #q8
#
# Act as a professional business writer. Write an email to my manager requesting one day's leave due to a personal reason. The audience is my manager, the tone should be polite and professional, and the response should be within 120 words.

# %% [markdown]
# #q9
#
# Act as an experienced HR Manager and draft a short policy note explaining the company's work-from-home guidelines for employees.

# %% [markdown]
# #q10
#
# I am a final-year engineering student preparing for a job interview. Help me answer the interview question, "Tell me about yourself." Highlight my education, technical skills, projects, strengths, and career goals in a confident and professional tone.

# %% [markdown]
# #q11
#
# Explain Blockchain Technology in exactly 80 words. Do not use technical jargon. Make the explanation simple enough for someone with no technical background.

# %% [markdown]
# #q12
#
# Role: [ROLE]
#
# Task: [TASK]
#
# Context: [CONTEXT]
#
# Instructions:
# - Explain the topic clearly.
# - Use simple language.
# - Include relevant examples if needed.
#
# Constraints:
# - [CONSTRAINTS]
#
# Output Format:
# - [FORMAT]
#
#
# Example Placeholders:
#
# [ROLE] = AI Tutor
# [TASK] = Explain Machine Learning
# [CONTEXT] = First-year engineering student
# [CONSTRAINTS] = Maximum 150 words
# [FORMAT] = Bullet points

# %% [markdown]
# #q13
#
# Classify the following customer review as Positive, Negative, or Neutral. Return only the category.
#
# Review: "The delivery was fast, but the packaging was damaged."

# %% [markdown]
# #q14 - One Short Prompt
#
# Classify customer feedback as either Complaint or Compliment.
#
# Example:
# Feedback: "The support team solved my issue quickly."
# Category: Compliment
#
# Now classify this:
# Feedback: "The product arrived two days late and the box was damaged."

# %% [markdown]
# #q15
#
# Classify each sentence as Formal or Informal.
#
# Examples:
#
# "I would like to request leave for tomorrow." --> Formal
# "Hey, what's up?" --> Informal
# "Please submit the report by 5 PM." --> Formal
#
# Now classify these:
#
# "Can you send me the notes?"
# "Kindly attend the meeting at 10 AM."

# %% [markdown]
# #q16
#
# Summarize the text below in 5 bullet points.
#
# """
# Artificial Intelligence is transforming industries by automating tasks, improving decision-making, and enhancing customer experiences. It is widely used in healthcare, finance, education, and manufacturing to improve efficiency and accuracy.
# """

# %% [markdown]
# #17
#
# (a) Poor Prompt
#
# Explain databases.
#
# (b) Improved Prompt
#
# Explain databases in simple language to a first-year engineering student. Use easy-to-understand examples.
#
# (c) Final Prompt
#
# Explain databases to a first-year engineering student in simple language. Keep the answer within 150 words and present it with a definition, key features, and one real-world example using bullet points.

# %% [markdown]
# #18
#
# Act as a Career Counsellor. I am a final-year Computer Science student with skills in Python, SQL, Machine Learning, and Data Analysis. I enjoy solving real-world problems and working with data. Based on my background, recommend three suitable career paths, explain why each is a good fit, and list the skills I should improve to succeed.

# %% [markdown]
# #adavanced prompt engineering Techniques

# %% [markdown]
# #19
#
# Solve the following problem step by step and show all calculations. A product costs ₹3,500. A shop offers a 15% discount, then adds 5% tax on the discounted price. Calculate the final amount to be paid and explain each step clearly.

# %% [markdown]
# #20
#
# A car travels 180 km at a speed of 60 km/h. Find the time taken using two different approaches. Compare both methods and select the most reliable final answer with a brief explanation.

# %% [markdown]
# #21
#
# Before answering, explain the general reasons why two products with similar features can have different prices. Then apply those principles to compare an Apple iPhone and an Android phone with similar specifications.

# %% [markdown]
# #22prompt Decompositon
#
# Prompt 1:
#
# Identify the target audience and business goals for a new bakery.
#
# Prompt 2:
#
# Suggest the best social media platforms and content ideas for the bakery.
#
# Prompt 3:
#
# Create a one-month posting schedule with content types and posting frequency.
#
# Prompt 4:
#
# Recommend marketing strategies, budget allocation, and success metrics for the campaign.

# %% [markdown]
# #23prompt Chain
#
# Prompt 1:
#
# Read the article and extract the key points in bullet form.
#
# Prompt 2:
#
# Using the extracted key points, write a concise summary in about 150 words.
#
# Prompt 3:
#
# Using the summary, create a 5-slide presentation outline with slide titles and key points.

# %% [markdown]
# #24self reflection Prompt
# Explain the benefits of Artificial Intelligence in healthcare. After answering, review your response for factual errors, missing information, and unclear explanations. Then provide an improved version of the answer.

# %% [markdown]
# #25 critique And Revise prompt
#
# Draft a short apology email to a client for a delayed delivery. Then critique the email for tone, clarity, and professionalism. Finally, revise the email based on your feedback and provide the improved version.

# %% [markdown]
# #prompting for diff task

# %% [markdown]
# #Q26 – Text Generation Prompt
#
# Prompt:
#
# Act as a professional content writer. Write a 300-word LinkedIn post announcing a new AI Training Program at Cambridge Infotech for working professionals. Highlight the course benefits, practical learning, career opportunities, and end with a call to action.

# %% [markdown]
# #27 – Summarization Prompt
#
# Prompt:
#
# Summarize the following research article into exactly 5 bullet points. Focus only on the key findings and ignore the background information. Keep each bullet concise and informative.

# %% [markdown]
# #Q28 – Classification Prompt
#
# Prompt:
#
# Classify the following customer support messages into Complaint, Inquiry, or Feedback. Return only the category for each message.
#
# "My order arrived damaged."
# "What is the warranty period for this product?"
# "The app is very easy to use."
# "I haven't received my refund yet."
# "Do you offer international shipping?"

# %% [markdown]
# #Q29 – Information Extraction Prompt
#
# Prompt:
#
# Extract the following details from the candidate profile: Name, Job Title, Years of Experience, and Key Skills.
#
# Candidate Profile:
# Riya Sharma is a Data Analyst with 4 years of experience. She is skilled in Python, SQL, Power BI, and Excel.

# %% [markdown]
# #Q30 – Translation Prompt
#
# Prompt:
#
# Translate the following paragraph into Hindi. Preserve technical terms and use natural, everyday language.
#
# Paragraph:
# Renewable energy comes from natural sources such as sunlight, wind, and water. It helps reduce pollution and supports a cleaner environment for future generations.

# %% [markdown]
# #Q31 – Rewriting/Transformation Prompt
#
# Prompt:
#
# Rewrite the following message in Professional, Friendly, and Formal tones.
#
# Message:
# "hey can u pls send the report by tmrw eod, thanks"

# %% [markdown]
# #Q32 – Context-Based Question Answering Prompt
#
# Prompt:
#
# Read the context below and answer the question using only the provided information.
#
# Context:
# Python is a popular programming language known for its simple syntax and versatility. It is widely used in web development, data science, machine learning, and automation. Python has a large community and many open-source libraries.
#
# Question:
# Name any two fields where Python is commonly used.

# %% [markdown]
# #structured output prompting

# %% [markdown]
# #Q33 – Bullet Point Prompt
#
# Prompt:
#
# Explain the advantages of remote work in exactly 6 bullet points. Do not include any introduction or conclusion—return only the bullet points.

# %% [markdown]
# #Q34 – Table Prompt
#
# Prompt:
#
# Compare Machine Learning and Deep Learning in a table with the following columns: Definition, Data Requirement, and Typical Use Case. Keep the explanation simple and beginner-friendly.

# %% [markdown]
# #Q35 – JSON Prompt
#
# Prompt:
#
# Extract the candidate information from the resume below and return it in the following JSON format:
#
# {
#   "name": "",
#   "role": "",
#   "experience_years": "",
#   "skills": []
# }
#
# Resume:
# Ananya Rao is a Machine Learning Engineer with 5 years of experience. She is skilled in Python, TensorFlow, SQL, and Docker.

# %% [markdown]
# #Q36 – XML Prompt
#
# Prompt:
#
# Extract the candidate information below and return it in XML format using proper opening and closing tags.
#
# Resume:
# Ananya Rao is a Machine Learning Engineer with 5 years of experience. She is skilled in Python, TensorFlow, SQL, and Docker.

# %% [markdown]
# #Q37 – Schema-Based Prompt
#
# Prompt:
#
# Extract the following product review information using this schema:
#
# product_name
# rating
# sentiment
# main_complaint
#
# If any field cannot be determined, return null instead of guessing.
#
# Review:
# The XYZ Bluetooth Speaker has great sound quality, but its battery drains quickly.

# %% [markdown]
# #Q38 – JSON Output Prompt
#
# Prompt:
#
# Read the customer complaint below. Classify it into one of these categories: Billing, Product, or Delivery. Identify the main issue, suggest a solution, and return the result as a single JSON object.
#
# Complaint:
# "My package arrived three days late and the box was damaged."

# %% [markdown]
# #Q39 – CSV Output Prompt
#
# Prompt:
#
# Convert the following business requirement into a CSV-style output with clearly labeled columns and sample matching records.
#
# Requirement:
# Find all customers who spent more than ₹10,000 last month.
#
# Include columns: Customer_ID, Customer_Name, Total_Spent, Month.

# %% [markdown]
# #prompting for coding

# %% [markdown]
# #Q40 – Code Generation Prompt
#
# Prompt:
#
# Role: You are an experienced Python developer.
# Language: Python
# Task: Write a function to check whether a given number is prime.
# Requirements: Include error handling for negative numbers, use comments, and make the code beginner-friendly.
# Input: An integer entered by the user.
# Output: Display whether the number is prime or not.

# %% [markdown]
# #Q41 – Code Explanation Prompt
#
# Prompt:
#
# Explain the following Python code line by line to a complete beginner. For each line, explain what it does and why it is used.
#
# numbers = [2, 4, 6, 8, 10]
# total = sum(numbers)
# average = total / len(numbers)
# print("Average:", average)
# print("Done")

# %% [markdown]
# #Q42 – Debugging Prompt
#
# Prompt:
#
# Debug the following Python code. Explain the cause of the error, provide the corrected code, and explain the changes.
#
# numbers = [1, 2, 3]
# print(numbers[5])
#
# Error Message:
#
# IndexError: list index out of range
#
# Expected Output:
#
# 3

# %% [markdown]
# #Q43 – Code Optimization Prompt
#
# Prompt:
#
# Optimize the following Python function to improve its performance while keeping the output exactly the same. Compare the original and optimized versions and explain the improvements.
#
# def square_numbers(nums):
#     result = []
#     for i in nums:
#         result.append(i * i)
#     return result

# %% [markdown]
# #Q44 – Code Refactoring Prompt
#
# Prompt:
#
# Refactor the following Python code by creating proper functions, using meaningful variable names, and following PEP 8 coding standards. Do not change the program's final output.
#
# a=[1,2,3]
# s=0
# for i in a:
#     s=s+i
# print(s)

# %% [markdown]
# #Q45 – Unit Testing Prompt
#
# Prompt:
#
# Generate Python unittest test cases for a function that calculates the average of a list of numbers. Include 3 normal test cases, 2 edge cases, and 2 invalid-input test cases. Provide the complete test code.

# %% [markdown]
# #Q46 – SQL Query Prompt
#
# Prompt:
#
# Convert the following business requirement into a correct SQL query.
#
# Requirement: List all employees whose department is Sales and salary is above ₹60,000.
#
# Table Name: employees
#
# Columns: employee_id, name, department, salary

# %% [markdown]
# #prompting for Data Analysis

# %% [markdown]
# #Q47 – Dataset Understanding Prompt
#
# Prompt:
#
# Act as a Senior Data Analyst. Analyze a sales dataset containing customer orders and describe the number of rows, columns, data types, missing values, and possible data quality issues. Present the findings in a clear and structured format.

# %% [markdown]
# #Q48 – Data Cleaning Prompt
#
# Prompt:
#
# Analyze the following dataset description and identify the columns with missing values. Suggest the most appropriate treatment method (remove, mean/median/mode imputation, or other suitable techniques) for each missing column, along with a brief justification.

# %% [markdown]
# #Q49 – Exploratory Data Analysis (EDA) Prompt
#
# Prompt:
#
# Perform an Exploratory Data Analysis (EDA) on a sales dataset containing the columns Date, Product, Region, and Revenue. Identify important patterns, outliers, trends, and relationships between the variables. Summarize the key findings.

# %% [markdown]
# #Q50 – Data Visualization Prompt
#
# Prompt:
#
# For a sales dataset containing Date, Product, Region, and Revenue, suggest three appropriate charts. For each chart, specify:
#
# Chart Type
# X-axis
# Y-axis
# Business question the chart answers

# %% [markdown]
# Q51 – Machine Learning Model Selection Prompt
#
# Prompt:
#
# A dataset has Customer_Churn as the target variable. Suggest suitable machine learning algorithms for predicting customer churn. Explain why each algorithm is appropriate, describe the key preprocessing steps, and recommend suitable evaluation metrics.

# %% [markdown]
# #Q52 – Business Insight Prompt
#
# Prompt:
#
# Analyze the given business dataset from a business perspective. Identify important trends, potential risks, business opportunities, and recommended actions. Focus on meaningful business insights rather than simply describing the data.

# %% [markdown]
# #Q53 – Data Analysis Prompt Template
#
# Prompt Template:
#
# Role:
# [ROLE]
#
# Dataset Description:
# [DATASET_DESCRIPTION]
#
# Business Objective:
# [BUSINESS_OBJECTIVE]
#
# Tasks:
# - Understand the dataset.
# - Check data quality and missing values.
# - Perform Exploratory Data Analysis (EDA).
# - Suggest suitable visualizations.
# - Identify key business insights.
# - Recommend appropriate machine learning models (if applicable).
# - Provide actionable recommendations.
#
# Output Format:
# Present the results using headings, bullet points, and tables where appropriate.
